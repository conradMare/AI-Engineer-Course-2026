# %% [markdown]
# Add a fifth meal: "Soup".

# %%
Menu = {'meal_1':'Spaghetti', 'meal_2':'Fries', 'meal_3':'Hamburger', 'meal_4':'Lasagna'}
Menu['meal_5'] = 'Soup'

# %%
Menu
# Out:
# {'meal_1': 'Spaghetti',
#  'meal_2': 'Fries',
#  'meal_3': 'Hamburger',
#  'meal_4': 'Lasagna',
#  'meal_5': 'Soup'}
