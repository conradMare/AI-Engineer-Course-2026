# %%
Participants = ['John', 'Celia', 'Grogory', 'Cate']
Participants
# Out:
# ['John', 'Celia', 'Grogory', 'Cate']

# %%
Participants[1]
# Out:
# 'Celia'

# %%
Participants[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Participants[4]
#
# IndexError: list index out of range

# %%
Participants[-1]
# Out:
# 'Cate'

# %%
Participants[3] = 'Maria'

# %%
Participants
# Out:
# ['John', 'Celia', 'Grogory', 'Maria']

# %%
del Participants[2]

# %%
Participants
# Out:
# ['John', 'Celia', 'Maria']

# %%
Participants
# Out:
# ['John', 'Celia', 'Maria']
