# %%
# Tuples are immutable - NOTE: A tuple is written with "()"

# %%
x = (40, 41, 42)
x
# Out:
# (40, 41, 42)

# %%
# Tuples are the default sequence type in Python!

# %%
y = 50, 51, 5
y
# Out:
# (50, 51, 5)

# %%
a, b, c = 1, 2, 3
c
# Out:
# 3

# %%
x[0]
# Out:
# 40

# %%
List_1 = [x,y]
List_1
# Out:
# [(40, 41, 42), (50, 51, 5)]

# %%
(age, years_of_school) = "30,17".split(",")
print(age)
print(years_of_school)
# Out:
# 30
# 17

# %%
def square_info(x):
    A = x **2
    P = 4 * x
    print("Area and Perimeter:")
    return(A,P)

square_info(3)
# Out:
# Area and Perimeter:
# (9, 12)
