# %%
Participants = ['John', 'Jane', 'Jim', 'Bucky']

# %%
print(Participants)
# Out:
# ['John', 'Jane', 'Jim', 'Bucky']

# %%
Participants[1] = 'George'
print(Participants)
# Out:
# ['John', 'George', 'Jim', 'Bucky']

# %%
del (Participants[1])
print(Participants)
# Out:
# ['John', 'Jim', 'Bucky']

# %%
Participants.append('Vic')

# %%
print(Participants)
# Out:
# ['John', 'Jim', 'Bucky', 'Vic']

# %%
Participants.extend(['Liz', 'Fran'])
Participants
# Out:
# ['John', 'Jim', 'Bucky', 'Vic', 'Liz', 'Fran']

# %%
print ('The first guest is: ' + Participants[0] + '.')
# Out:
# The first guest is: John.

# %%
Numbers = [1, 2, 3, 4, 5]
print(Numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
print ('First num in List of Nums: ' + str(Numbers))
# Out:
# First num in List of Nums: [1, 2, 3, 4, 5]

# %%
len('Dolphin')
# Out:
# 7

# %%
len(Participants)
# Out:
# 6
