# %% [markdown]
# Using slicing, extract the last 4 elements from the list.

# %%
Numbers = [15, 40, 50, 100, 115, 140]
Numbers[:-4]
# Out:
# [15, 40]

# %%
Numbers[:-2]
# Out:
# [15, 40, 50, 100]

# %%
Numbers[1:5]
# Out:
# [40, 50, 100, 115]

# %%
Numbers[-4:]
# Out:
# [50, 100, 115, 140]
