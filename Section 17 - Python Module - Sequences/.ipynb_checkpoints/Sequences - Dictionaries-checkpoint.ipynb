# %%
# Dictionaries are written with "{}" -> Key Value pairs
# Tuples are written with "()" -> Immutable
# Lists are written with "[]" -> Like an Array in JS

# %%
dict = {'k1': "cat", 'k2': "dog", 'k3': "mouse", 'k4': "fish"}
dict
# Out:
# {'k1': 'cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish'}

# %%
dict['k1']
# Out:
# 'cat'

# %%
dict['k3']
# Out:
# 'mouse'

# %%
dict['k5'] = 'parrot'

# %%
dict
# Out:
# {'k1': 'cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish', 'k5': 'parrot'}

# %%
dict['k2'] = 'squirrel'

# %%
dict
# Out:
# {'k1': 'cat', 'k2': 'squirrel', 'k3': 'mouse', 'k4': 'fish', 'k5': 'parrot'}

# %%
# List embedded in a dictionary

# %%
dep_workers = {'dep1': 'Peter', 'dep2': ['Jennifer', 'Rob', 'Sarah']}

# %%
dep_workers['dep2']
# Out:
# ['Jennifer', 'Rob', 'Sarah']

# %%
dep_workers['dep2'][2]
# Out:
# 'Sarah'

# %%
# Different way of creating a dictionary

# %%
Team = {}
Team['Point Guard'] = 'Dirk'
Team['Shooting Guard'] = 'Al'
Team['Small Forward'] = 'Sean'
Team['Power Forward'] = 'Alexander'
Team['Center'] = 'Hector'

# %%
print(Team)
# Out:
# {'Point Guard': 'Dirk', 'Shootin Guard': 'Al', 'Small Forward': 'Sean', 'Power Forward': 'Alexander', 'Center': 'Hector'}

# %%
print(Team['Center'])
# Out:
# Hector

# %%
print (Team.get('Center'))
# Out:
# Hector

# %%
print(Team.get('Coach'))
# Out:
# None
