# %%
Participants = ['John', 'Leila', 'Maria', 'Dwayne', 'George', 'Catherine']
Participants
# Out:
# ['John', 'Leila', 'Maria', 'Dwayne', 'George', 'Catherine']

# %%
Participants[1:3]
# Out:
# ['Leila', 'Maria']

# %%
Participants[4:6]
# Out:
# ['George', 'Catherine']

# %%
Participants[:2]
# Out:
# ['John', 'Leila']

# %%
Participants[4:]
# Out:
# ['George', 'Catherine']

# %%
Participants[-2:]
# Out:
# ['George', 'Catherine']

# %%
# Additonal slicing methods:

# %%
Participants = ['John', 'Peter', 'Maria', 'Leila', 'Dwayne', 'Catherine']

# %%
Participants.index('Maria')
# Out:
# 2

# %%
# Creating a list within a list (Embedding)

# %%
Newcomers = ['Joshua', 'Britney']

# %%
Bigger_List = [Participants, Newcomers]
Bigger_List
# Out:
# [['John', 'Peter', 'Maria', 'Leila', 'Dwayne', 'Catherine'],
#  ['Joshua', 'Britney']]

# %%
Participants.sort()
Participants
# Out:
# ['Catherine', 'Dwayne', 'John', 'Leila', 'Maria', 'Peter']

# %%
Participants.sort(reverse=True)
Participants
# Out:
# ['Peter', 'Maria', 'Leila', 'John', 'Dwayne', 'Catherine']

# %%
Numbers = [1, 2, 3, 4, 5]
Numbers.sort()
Numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
Numbers.sort(reverse=True)
Numbers
# Out:
# [5, 4, 3, 2, 1]
