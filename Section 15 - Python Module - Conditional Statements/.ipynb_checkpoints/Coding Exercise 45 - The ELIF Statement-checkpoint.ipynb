# %% [markdown]
# Create the following piece of code: If x > 200, print out "Big"; If x > 100 and x <= 200, print out "Average"; and If x <= 100, print out "Small". Use the if, elif, and else keywords in your code.

# %%
def compare_values(x):
    if x > 200:
        return "Big"
    elif x > and x <= 200:
        return "Average"
    else:
        return "Small"
# Out:
#   Cell In[1], line 4
#     elif x > and x <= 200:
#              ^
# SyntaxError: invalid syntax

# %%
def compare_values(x):
    if x > 200:
        return "Big"
    elif (x > 100 and x <= 200):
        return "Average"
    else:
        return "Small"

# %%
print (compare_values(201))
# Out:
# Big

# %%
print (comapre_values(150))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print (comapre_values(150))
#
# NameError: name 'comapre_values' is not defined

# %%
print (compare_values(150))
# Out:
# Average

# %%
print (compare_values(90))
# Out:
# Small
