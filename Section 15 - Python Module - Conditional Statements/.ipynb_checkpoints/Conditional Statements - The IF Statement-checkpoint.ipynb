# %%
if 5 == 15 / 3:
    print('Hello Monty Python')
# Out:
# Hello Monty Python

# %%
if 5 == 18 / 3:
    print('Oops!')

# %%
if 5 != 3 * 6:
    print ('Hello Again Monty Py')
# Out:
# Hello Again Monty Py
