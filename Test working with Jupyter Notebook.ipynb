# %%
x= [1, 2, 3, 4, 5]
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y = x
y
# Out:
# [1, 2, 3, 4, 5]

# %%
if (x == y):
    print("Hello World!")
# Out:
# Hello World!

# %%
y = [5, 4, 3, 2, 1];
if (x == y):
    print("Hello World!")
elif (x != y):
    print("Not Hello World!")
# Out:
# Not Hello World!
