# %%
# Comments are senteces not read by the computer

# %%
# And yes, the above line is a comment

# %%
# This is a comment and not code
print (7, 2)
# Out:
# 7 2

# %%
# Comment 1
# Comment 2
print (float(100))
# Out:
# 100.0
