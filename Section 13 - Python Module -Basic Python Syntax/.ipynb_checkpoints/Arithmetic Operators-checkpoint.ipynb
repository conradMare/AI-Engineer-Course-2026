# %%
1 + 2
# Out:
# 3

# %%
3 - 5
# Out:
# -2

# %% [markdown]
# # 3 and 5 are called Operands

# %% [markdown]
# # + and - are called Arithmetic Operators

# %%
15 / 3
# Out:
# 5.0

# %%
16 / 3
# Out:
# 5.333333333333333

# %%
x = int(16/3)

# %%
print (x)
# Out:
# 5

# %%
# The above float happened becasue I am using Python 3, with Python 2 it would have show an int

# %%
y = float(x)
print (y)
# Out:
# 5.0

# %%
x = 16/3

# %%
x
# Out:
# 5.333333333333333

# %%
y = int(x)
print (y)
# Out:
# 5

# %%
# To get the remainder of 16 / 3, use % (modulo)

# %%
z = 16 % 3
print (z)
# Out:
# 1

# %%
a = 5 * 3
print (a)
# Out:
# 15

# %%
z = x
print (z)
# Out:
# 1

# %%
# To raise the left hand operand to the power of the right operand use **

# %%
5 ** 3
# Out:
# 125
