# %% [markdown]
# Using indentation, write a function called ten() that takes any argument x, assigns the value 10 to x, and then returns x.
#
# Call the function with an argument of 3 and print the result.

# %%
def ten():
    x = 10
    return x
print(ten(3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2     x = 10
#       3     return x
# ----> 4 print(ten(3))
#
# TypeError: ten() takes 0 positional arguments but 1 was given

# %%
def ten(x):
    x = 10
    return x
print (ten(3))
# Out:
# 10
