# %%
def simple():
    print("Py time!")

# %%
simple()
# Out:
# Py time!

# %%
def plus_ten(x):
    return x + 10

# %%
plus_ten(5)
# Out:
# 15

# %%
plus_ten(2)
# Out:
# 12

# %%
def plus_ten(a):
    result = a + 10
    return result

# %%
plus_ten(2)
# Out:
# 12

# %%
# print - does not affect the the calculation of the output

# %%
# return - does not visualize the output
# return - it specifies waht a certain function is supposed to give back

# %%
def plus_ten(x):
    result = x + 10
    print("Outcome")
    return result

# %%
plus_ten(10)
# Out:
# Outcome
# 20
