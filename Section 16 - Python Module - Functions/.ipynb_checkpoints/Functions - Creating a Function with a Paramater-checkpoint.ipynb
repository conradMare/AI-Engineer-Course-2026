# %%
def simple():
    print("Py time!")

# %%
simple()
# Out:
# Py time!

# %%
def plus_ten(a):
    return a + 10

# %%
plus_ten(2)
# Out:
# 12

# %%
plus_ten(5)
# Out:
# 15

# %%
# retrun can only be used ONCE in a function!!!
