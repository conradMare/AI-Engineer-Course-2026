# %%
type(10)
# Out:
# int

# %%
float(1)
# Out:
# 1.0

# %%
int(1.0)
# Out:
# 1

# %%
str(1)
# Out:
# '1'

# %%
# max() -> returns the highest value from a sequence of numbers

# %%
max(10,20,30)
# Out:
# 30

# %%
# min() -> returns the lowest value from a sequence of numbers

# %%
min(123,490,1000,22)
# Out:
# 22

# %%
# abs() -> allows you to obtain the absolute value of its argument

# %%
z = -20
abs(z)
# Out:
# 20

# %%
# sum() -> calculates the sum of all the elements in alist designated as a argument

# %%
list_1 = [1,2,3,4]

# %%
sum(list_1)
# Out:
# 10

# %%
# round(x, y) -> returns the float of it's argument (x), rounded to a specified number of digits (y) after a decimal point

# %%
round(3.555, 2)
# Out:
# 3.56

# %%
# pow(x, y) -> returns x to the power of y

# %%
pow(2, 10)
# Out:
# 1024

# %%
# len() -> returns the number of elements in an object

# %%
len('supercalifragilisticexpialidocious')
# Out:
# 34

# %%
len('no,supercalifragilisticexpialidocious,is not the longest word in English')
# Out:
# 72
