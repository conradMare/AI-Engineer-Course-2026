# %% [markdown]
# Logical Operators: (Boolean Operators)
# NOT - AND -OR

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
# 'not' leads to the opposite of the given statement

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
3 > 5 and 10 <= 20
# Out:
# False

# %%
# Order of the operators are:
# 1. not
# 2. and
# 3. or

# %%
True and not True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
False and not True or True
# Out:
# True

# %%
False and not True and True
# Out:
# False

# %%
True and not False or True
# Out:
# True

# %% [markdown]
# Identity Operators: is, is not (similar to the == sign)

# %%
5 is 6
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\phill\AppData\Local\Temp\ipykernel_8760\2929037671.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   5 is 6
# False

# %%
5 is string(6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 5 is string(6)
#
# NameError: name 'string' is not defined

# %%
x = 5
y = 6
x is y
# Out:
# False

# %%
x is not y
# Out:
# True
