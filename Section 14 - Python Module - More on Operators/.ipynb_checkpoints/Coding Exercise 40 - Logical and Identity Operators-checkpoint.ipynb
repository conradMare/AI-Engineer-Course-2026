# %%
# Using an identity operator, verify that 10 is not the same as 12.

# %%
10 is not 12
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\phill\AppData\Local\Temp\ipykernel_9672\2742155778.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   10 is not 12
# True

# %%
x = 10
y = 12
x is not 12
# Out:
# <>:3: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\phill\AppData\Local\Temp\ipykernel_9672\2078715173.py:3: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   x is not 12
# True

# %%
x is not y
# Out:
# True
