# %%
x1 = 5

# %%
type(x1)
# Out:
# int

# %%
type(-6)
# Out:
# int

# %%
type(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 type(true)
#
# NameError: name 'true' is not defined

# %%
x2 = 4.75

# %%
type(x2)
# Out:
# float

# %%
int(x2)
# Out:
# 4

# %%
float(x1)
# Out:
# 5.0

# %%
x3 = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x3 = true
#
# NameError: name 'true' is not defined

# %%
x3 = True

# %%
type(x3)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # int = 1 || 2 || 3 -> No decimal point

# %% [markdown]
# # float = 1.0 || 2.0 -> Decimal point

# %% [markdown]
# # Boolean = True or False (Note the capital letter, unlike JS)
