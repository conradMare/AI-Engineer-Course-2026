# %%
'It\'s cool, isn\'t it'
# Out:
# "It's cool, isn't it"

# %%
'It\'s cool, isn\'t it?'
# Out:
# "It's cool, isn't it?"

# %%
print('It\'s cool, isn\'t it?')
# Out:
# It's cool, isn't it?

# %%
a = "It's"

# %%
b = "cool"

# %%
c = ", isn't"

# %%
d = "it?"

# %%
print (a, b, c, d)
# Out:
# It's cool , isn't it?
