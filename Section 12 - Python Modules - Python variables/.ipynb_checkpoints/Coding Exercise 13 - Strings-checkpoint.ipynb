# %%
# Produce an output equal to -> Click "OK"

# %%
print('Click "OK"')
# Out:
# Click "OK"

# %%
a = 'Click'

# %%
b = "OK"

# %%
print (a + b)
# Out:
# ClickOK

# %%
print (a + ' ' + b)
# Out:
# Click OK

# %%
a = 'Click '
b = '"OK"'

# %%
print (a, b)
# Out:
# Click  "OK"
