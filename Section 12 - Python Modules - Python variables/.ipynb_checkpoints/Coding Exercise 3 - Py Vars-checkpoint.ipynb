# %%
a, b, c, d = (10, 20, 30, 40)

# %%
print (a)
# Out:
# 10

# %%
print(b)
# Out:
# 20

# %%
print (c)
# Out:
# 30

# %%
print (d)
# Out:
# 40

# %%
print (a, b, c, d)
# Out:
# 10 20 30 40

# %%
a, d = (50, 60)

# %%
print (a, b, c, d)
# Out:
# 50 20 30 60
