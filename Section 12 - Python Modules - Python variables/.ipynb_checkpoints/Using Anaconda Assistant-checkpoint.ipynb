# %%
George
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 George
#
# NameError: name 'George' is not defined

# %%
# If you want to define a variable named George
George = "some value"  # Assign a value to the variable

# OR

# If you meant to use "George" as a string
print("George")  # Use quotes to indicate it's a string literal
# Out:
# George

# %%
y = 10
print(y + 'dollars')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 y = 10
# ----> 2 print(y + 'dollars')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # Assistant
# The error occurs because you're trying to add an integer (`y` which is 10) directly to a string (`'dollars'`). In Python, you can't add different data types like this without converting them to the same type first.
#
# Would you like me to provide the corrected code?

# %%
y = 10
print(str(y) + ' dollars')  # Convert y to string before concatenation
# Alternative solution:
# print(f"{y} dollars")     # Using f-string for cleaner formatting
# Out:
# 10 dollars

# %%
print(f'{y} dollars')
# Out:
# 10 dollars
