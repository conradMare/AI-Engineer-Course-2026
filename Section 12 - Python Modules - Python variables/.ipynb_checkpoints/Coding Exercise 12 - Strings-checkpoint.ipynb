# %%
# Fix the string

# %%
'Don't be shy
# Out:
#   Cell In[2], line 1
#     'Don't be shy
#          ^
# SyntaxError: invalid syntax

# %%
'Don\'t be shy'
# Out:
# "Don't be shy"

# %%
"Don't be shy"
# Out:
# "Don't be shy"
