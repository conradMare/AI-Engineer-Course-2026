# %%
list_1 = [1, 2]
list_1
# Out:
# [1, 2]

# %%
list_2 = [34, 45]
list_2
# Out:
# [34, 45]

# %%
list_1.extend(list_2)

# %% [markdown]
# # Use shift + tab inside the parentheses to view description
# str()
